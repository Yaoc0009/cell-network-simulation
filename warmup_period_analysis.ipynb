# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
no_res_data = pd.read_csv("warmup_period_no_reservation_time.csv")[['time', 'blocked_rate', 'dropped_rate']]
start_indexes = no_res_data[no_res_data['time'] == 0].index.tolist()

# %%
warmup_period = 300000
# Set the display
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(20, 8)}, font_scale=1.3)

# Set 6 subplots
fig, axs = plt.subplots(nrows=2, ncols=5)
fig.tight_layout(pad=1.0)

for i in range(len(start_indexes)):
    # if i == len(start_indexes) - 1:
    #     single_data = no_res_data.iloc[start_indexes[i]:][['blocked_rate', 'dropped_rate']].reset_index(drop=True)
    # else:
    single_data = no_res_data.iloc[start_indexes[i]:start_indexes[i] + warmup_period][['blocked_rate', 'dropped_rate']].reset_index(drop=True)
    sns.lineplot(data=single_data, ax=axs[i//5, i%5])

fig.savefig("warmup_period_analysis_no_reservation.png")

# %%
no_res_data = pd.read_csv("warmup_period_one_reservation_time.csv")[['generated_calls', 'blocked_rate', 'dropped_rate']]
start_indexes = no_res_data[no_res_data['time'] == 0].index.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10016/4011710686.py in <module>
# ----> 1 no_res_data = pd.read_csv("warmup_period_one_reservation_time.csv")[['generated_calls', 'blocked_rate', 'dropped_rate']]
#       2 start_indexes = no_res_data[no_res_data['time'] == 0].index.tolist()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
warmup_period = 300000
# Set the display
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(20, 8)}, font_scale=1.3)

# Set 6 subplots
fig, axs = plt.subplots(nrows=2, ncols=5)
fig.tight_layout(pad=1.0)

for i in range(len(start_indexes)):
    # if i == len(start_indexes) - 1:
    #     single_data = no_res_data.iloc[start_indexes[i]:][['blocked_rate', 'dropped_rate']].reset_index(drop=True)
    # else:
    single_data = no_res_data.iloc[start_indexes[i]:start_indexes[i] + warmup_period][['blocked_rate', 'dropped_rate']].reset_index(drop=True)
    sns.lineplot(data=single_data, ax=axs[i//5, i%5])

fig.savefig("warmup_period_analysis_one_reservation.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10016/2137102716.py in <module>
#       8 fig.tight_layout(pad=1.0)
#       9
# ---> 10 for i in range(len(start_indexes)):
#      11     if i == len(start_indexes) - 1:
#      12         single_data = no_res_data.iloc[start_indexes[i]:][['blocked_rate', 'dropped_rate']].reset_index(drop=True)
#
# NameError: name 'start_indexes' is not defined
